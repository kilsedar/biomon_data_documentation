# %% [markdown]
# # Technical sheet
#
# ## Indicator
#
# | a | b | c | d | e |
# |:---:|:---:|:---:|:---:|:---:|
# | 1 | Aenean viverra erat accumsan urna imperdiet, id viverra erat volutpat. Etiam ligula velit, molestie quis finibus quis, fringilla sit amet neque. | Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer fringilla viverra dui. Pellentesque volutpat eros nec tellus condimentum luctus at sodales nisl. | Vivamus hendrerit hendrerit turpis in tristique. Morbi fringilla ornare tellus vel condimentum. | Vestibulum ac ultricies ipsum. |
#
# * a formula: $$f'(a) = \lim_{x \to a} \frac{f(x) - f(a)}{x-a}$$
#
# * a list item: ...
#
# * another list item: ...
#
# ### Interpretation
#
# Sed vitae tellus ipsum. Etiam nec eros quam. Integer fringilla lorem metus, ut interdum orci hendrerit vel. Duis ac tincidunt nunc. Phasellus in consequat urna. Quisque blandit elit leo, ut mattis ex viverra sed. Aliquam pulvinar lectus quis faucibus ultrices. In malesuada lectus id auctor venenatis$^{1}$.
#
# ### More infomation
#
# ($S = MKL_{Z} - CEK_{f} + TST_{f}$)

# %% [markdown]
# ## Information on the input data
#
# 1. a
# 2. b
# 3. c
#
# [a link](https://ec.europa.eu/jrc/en)

# %% [markdown]
# &nbsp;
#
# $^{1}$: a footnote
